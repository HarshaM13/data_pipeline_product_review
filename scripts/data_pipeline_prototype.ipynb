# %% [markdown]
# ## Practice: Data pipeline Hands-on Lab

# %% [markdown]
# Goal: Understand ETL logic.

# %% [markdown]
# We would need first to extract data from a MongoDB database comtaining customer reviews.

# %%
#pip install mongomock

# %% [markdown]
# ## Connect to an in-memory MongoDB instance
#
# ---

# %%
import mongomock

# The code below create a simulated MongoDB client and database
client = mongomock.MongoClient() #not a real server for practicality and IT restrictions (stored in memory)
db = client.my_mock_database # database creation
review_collection = db.reviews # collection creation (collections are like tables in SQL)

# %% [markdown]
# ## Extract data from MongoDB

# %%
JSONL_path = "../data/product_reviews_sales.jsonl"

# %% [markdown]
# | **Column**      | **Type**           | **Description**                                                                | **Example**                                           |
# | --------------- | ------------------ | ------------------------------------------------------------------------------ | ----------------------------------------------------- |
# | `product_id`    | `int`              | Unique product ID                  | `3`                                                   |
# | `customer_id`   | `str`              | Unique identifier for the customer posting the review or making the purchase   | `"CUST_1042"`                                         |
# | `review_text`   | `str`              | Free-text product review written by a customer                                 | `"Great quality and fits perfectly! Will buy again."` |
# | `sale_date`     | `str` (ISO format) | Date of sale or review submission (YYYY-MM-DD)                                 | `"2024-11-09"`                                        |
# | `units_sold`    | `int`              | Quantity sold during this transaction or review context                        | `2`                                                   |

# %%
import json

# Load and parse all lines from the JSONL file
with open(JSONL_path, "r", encoding="utf-8") as f:
    data = [json.loads(line) for line in f]
    print(data)
# Out:
# [{'product_id': 1, 'customer_id': 'C101', 'review_text': 'Great quality backpack, fits my laptop perfectly. Could use more pockets.', 'sale_date': '2024-10-15', 'units_sold': 3}, {'product_id': 1, 'customer_id': 'C102', 'review_text': 'Good for daily use but straps feel a bit thin.', 'sale_date': '2024-10-17', 'units_sold': 1}, {'product_id': 2, 'customer_id': 'C103', 'review_text': 'Nice shirt, fits well and comfortable fabric.', 'sale_date': '2024-09-20', 'units_sold': 2}, {'product_id': 3, 'customer_id': 'C104', 'review_text': 'Excellent jacket for winter hikes, very warm!', 'sale_date': '2024-11-02', 'units_sold': 1}, {'product_id': 4, 'customer_id': 'C105', 'review_text': 'Size runs small. Material is okay for the price.', 'sale_date': '2024-09-28', 'units_sold': 2}, {'product_id': 5, 'customer_id': 'C106', 'review_text': 'Beautiful bracelet, gift for my partner and she loved it!', 'sale_date': '2024-10-10', 'units_sold': 1}, {'product_id': 6, 'customer_id': 'C107', 'review_text': 'Looks elegant but clasp broke after a week.', 'sale_date': '2024-10-22', 'units_sold': 1}, {'product_id': 7, 'customer_id': 'C108', 'review_text': 'Cute ring but smaller than expected. Packaging was nice.', 'sale_date': '2024-09-25', 'units_sold': 1}, {'product_id': 8, 'customer_id': 'C109', 'review_text': 'Pretty earrings but slightly heavy on ears.', 'sale_date': '2024-11-01', 'units_sold': 3}, {'product_id': 9, 'customer_id': 'C110', 'review_text': 'Solid drive, works out of the box, very fast transfers.', 'sale_date': '2024-10-02', 'units_sold': 4}, {'product_id': 10, 'customer_id': 'C111', 'review_text': 'SSD improved my old laptop speed massively.', 'sale_date': '2024-10-07', 'units_sold': 5}, {'product_id': 11, 'customer_id': 'C112', 'review_text': 'Reliable SSD with good price-performance balance.', 'sale_date': '2024-09-30', 'units_sold': 2}, {'product_id': 12, 'customer_id': 'C113', 'review_text': 'Great storage for gaming, plug-and-play setup.', 'sale_date': '2024-10-14', 'units_sold': 3}, {'product_id': 13, 'customer_id': 'C114', 'review_text': 'Decent monitor but colors feel slightly off compared to spec sheet.', 'sale_date': '2024-09-18', 'units_sold': 1}, {'product_id': 14, 'customer_id': 'C115', 'review_text': 'Incredible ultrawide monitor, perfect for multitasking.', 'sale_date': '2024-11-04', 'units_sold': 2}, {'product_id': 15, 'customer_id': 'C116', 'review_text': 'Warm and durable coat, ideal for skiing trips.', 'sale_date': '2024-10-26', 'units_sold': 2}, {'product_id': 16, 'customer_id': 'C117', 'review_text': 'Stylish jacket but zipper feels fragile.', 'sale_date': '2024-09-29', 'units_sold': 1}, {'product_id': 17, 'customer_id': 'C118', 'review_text': 'Good rain protection and comfortable fit.', 'sale_date': '2024-11-03', 'units_sold': 3}, {'product_id': 18, 'customer_id': 'C119', 'review_text': 'Soft fabric, fits well and nice color options.', 'sale_date': '2024-09-22', 'units_sold': 4}, {'product_id': 19, 'customer_id': 'C120', 'review_text': 'Lightweight and breathable, great for workouts.', 'sale_date': '2024-10-08', 'units_sold': 2}, {'product_id': 20, 'customer_id': 'C121', 'review_text': 'Casual T-shirt, good fit, print fades after few washes.', 'sale_date': '2024-09-27', 'units_sold': 5}]

# %%
#Insert all records into the collection using .insert_many()
result = review_collection.insert_many(data)

#count how many documents have been inserted
print(f"Inserted {len(result.inserted_ids)} documents into 'reviews' collection.")
# Out:
# Inserted 21 documents into 'reviews' collection.

# %%
#Let's check columns from data
sample = review_collection.find_one()
print("Fields in one document:", list(sample.keys()))
# Out:
# Fields in one document: ['product_id', 'customer_id', 'review_text', 'sale_date', 'units_sold', '_id']

# %%
import pandas as pd

# %%
df_reviews = pd.read_json(JSONL_path, lines=True)
df_reviews.head()
# Out:
#    product_id customer_id                                        review_text  \
# 0           1        C101  Great quality backpack, fits my laptop perfect...
# 1           1        C102     Good for daily use but straps feel a bit thin.
# 2           2        C103      Nice shirt, fits well and comfortable fabric.
# 3           3        C104      Excellent jacket for winter hikes, very warm!
# 4           4        C105   Size runs small. Material is okay for the price.
#
#     sale_date  units_sold
# 0  2024-10-15           3
# 1  2024-10-17           1
# 2  2024-09-20           2
# 3  2024-11-02           1
# 4  2024-09-28           2

# %%
import pandas as pd

df_reviews = pd.DataFrame((review_collection.find({})))
df_reviews.head()
# Out:
#    product_id customer_id                                        review_text  \
# 0           1        C101  Great quality backpack, fits my laptop perfect...
# 1           1        C102     Good for daily use but straps feel a bit thin.
# 2           2        C103      Nice shirt, fits well and comfortable fabric.
# 3           3        C104      Excellent jacket for winter hikes, very warm!
# 4           4        C105   Size runs small. Material is okay for the price.
#
#     sale_date  units_sold                                   _id
# 0  2024-10-15           3  9cce9adc-c3a7-11f0-8b0b-8cf8c5b66867
# 1  2024-10-17           1  9cce9add-c3a7-11f0-a806-8cf8c5b66867
# 2  2024-09-20           2  9cce9ade-c3a7-11f0-a325-8cf8c5b66867
# 3  2024-11-02           1  9cce9adf-c3a7-11f0-8595-8cf8c5b66867
# 4  2024-09-28           2  9ccec1f7-c3a7-11f0-824e-8cf8c5b66867

# %% [markdown]
# ## Extract data from an API

# %%
API_URL = "https://fakestoreapi.com/products"

# %% [markdown]
# The Fake Store API is a free, public REST API that provides mock e-commerce data for learning and testing.
# A REST API (Representational State Transfer API) is a style of web API that lets clients interact with a server using HTTP requests.
# Most REST APIs transfer data in JSON.

# %% [markdown]
# Fetch JSON data

# %%
import requests #popular Python library for making HTTP requests (GET, POST, PUT, DELETE, etc.).

#We send a GET request to the API endpoint to retrieve product data in JSON format:

resp = requests.get(API_URL, verify=False)   # simple GET, no auth #verify=False, by passes the request
products_json = resp.json()    # list of product
print(len(products_json), products_json[0])  # quick peek (count + first item)
# Out:
# 20 {'id': 1, 'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops', 'price': 109.95, 'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_t.png', 'rating': {'rate': 3.9, 'count': 120}}
# c:\Users\UKHSM003\OneDrive - WSP O365\Projecting Success\Level 7\Lessons\Module 14 - Data Pipeline\DayOne\.venv\lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'fakestoreapi.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
resp
# Out:
# <Response [200]>

# %%
#transform json data into a dataframe
products_df = pd.DataFrame(products_json)
products_df.head()
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...
# 3  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...
# 4  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...
#
#                         rating
# 0  {'rate': 3.9, 'count': 120}
# 1  {'rate': 4.1, 'count': 259}
# 2  {'rate': 4.7, 'count': 500}
# 3  {'rate': 2.1, 'count': 430}
# 4  {'rate': 4.6, 'count': 400}

# %%
# Flatten the nested 'rating' dictionary
rating_df = pd.json_normalize(products_df['rating'])

# %%
rating_df.head()
# Out:
#    rate  count
# 0   3.9    120
# 1   4.1    259
# 2   4.7    500
# 3   2.1    430
# 4   4.6    400

# %%
products_df= products_df.drop(columns=['rating']).join(rating_df)

# %%
products_df.head()
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  rate  count
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...   3.9    120
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...   4.1    259
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...   4.7    500
# 3  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...   2.1    430
# 4  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...   4.6    400

# %% [markdown]
# ### Data transformation: MERGE DATA

# %% [markdown]
# We are going to merge both dataframes/combined data from 2 different sources.

# %%
combined_df = df_reviews.merge(
    products_df,
    left_on="product_id",#productid from reviews
    right_on="id",#productid from products, API data
    how="left"         # keep all reviews, even if product missing
)
combined_df.head()
# Out:
#    product_id customer_id                                        review_text  \
# 0           1        C101  Great quality backpack, fits my laptop perfect...
# 1           1        C102     Good for daily use but straps feel a bit thin.
# 2           2        C103      Nice shirt, fits well and comfortable fabric.
# 3           3        C104      Excellent jacket for winter hikes, very warm!
# 4           4        C105   Size runs small. Material is okay for the price.
#
#     sale_date  units_sold                                   _id  id  \
# 0  2024-10-15           3  9cce9adc-c3a7-11f0-8b0b-8cf8c5b66867   1
# 1  2024-10-17           1  9cce9add-c3a7-11f0-a806-8cf8c5b66867   1
# 2  2024-09-20           2  9cce9ade-c3a7-11f0-a325-8cf8c5b66867   2
# 3  2024-11-02           1  9cce9adf-c3a7-11f0-8595-8cf8c5b66867   3
# 4  2024-09-28           2  9ccec1f7-c3a7-11f0-824e-8cf8c5b66867   4
#
#                                                title   price  \
# 0  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 3                                 Mens Cotton Jacket   55.99
# 4                               Mens Casual Slim Fit   15.99
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Your perfect pack for everyday use and walks i...  men's clothing
# 2  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 3  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 4  The color could be slightly different between ...  men's clothing
#
#                                                image  rate  count
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...   3.9    120
# 1  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...   3.9    120
# 2  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...   4.1    259
# 3  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...   4.7    500
# 4  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...   2.1    430

# %% [markdown]
# A left join means:
#
# Keep all rows from the left DataFrame (df_reviews)
#
# Only bring product info if a match exists
#
# If no matching product exists → fill with NaN

# %% [markdown]
# In real-world ETL, not all data sources align perfectly.
#
# Some reviews may refer to missing or discontinued products.
#
# A left join preserves your operational data (reviews) while flagging missing lookups for investigation or logging.

# %% [markdown]
# Why NOT use a full outer join in this case?
#
# A full outer join keeps everything from both tables, even when there’s no match:
#
# All reviews (even if the product is missing)
#
# All products (even if nobody reviewed them)
#
# But in a reviews → products lookup scenario, this usually adds noise, not value.

# %% [markdown]
# Let's save our combined dataset:

# %%
combined_df.to_csv("combined_df.csv")
