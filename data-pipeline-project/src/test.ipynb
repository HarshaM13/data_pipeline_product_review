# %%
f = open('../data/processed/reviews_products.processed.csv')

# %%
f
# Out:
# <_io.TextIOWrapper name='../data/processed/reviews_products.processed.csv' mode='r' encoding='cp1252'>

# %%
f.close()

# %%
g = open('../data/processed/reviews_products.processed.csv')

# %%
g.close()

# %%
#../data-pipeline-project/data/processed/
